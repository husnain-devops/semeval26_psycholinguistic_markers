# %% [markdown]
# # Marker Extraction - 5 Separate RoBERTa-Large-LoRA Models
#
# **Strategy**: Train 5 separate models (one per marker type) for better specialization
#
# - **Model**: RoBERTa-large with LoRA fine-tuning
# - **Approach**: 5 separate binary classifiers (O vs marker_type)
# - **Benefits**: Each model specializes in one marker type
# - **Expected**: Better accuracy than unified model

# %%
# Environment setup
import os
os.environ['TOKENIZERS_PARALLELISM'] = 'false'

import torch
import numpy as np

print('='*60)
print('Environment')
print('='*60)
print(f'PyTorch: {torch.__version__}')
print(f'GPU: {torch.cuda.get_device_name(0) if torch.cuda.is_available() else "CPU"}')
print('='*60)
